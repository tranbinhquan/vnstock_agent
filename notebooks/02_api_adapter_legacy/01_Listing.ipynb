# %% [markdown]
# # API Adapter - Listing
# Demo tự động các hàm trong class `Listing`.

# %%
from vnstock_data.api.listing import Listing

# Khởi tạo instance
instance = Listing(source='VCI')
# Out:
# 📦 **Vnstock 3.5.1 is available**
# Current version: 3.4.2
# Update: `pip install vnstock --upgrade`
# Release history: https://vnstocks.com/docs/tai-lieu/lich-su-phien-ban
# 📦 **Vnii 0.2.0 is available** (subscription)
# Current version: 0.1.9
# Update: `pip install --upgrade --extra-index-url https://vnstocks.com/api/simple vnii`
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='4f608abe-4408-4db6-a363-4a2250ff6c18'>
# ...

# %% [markdown]
# ### `all_bonds()`
# Retrieve all bonds (group='BOND').

# %%
df_all_bonds = instance.all_bonds()
display(df_all_bonds)
# Out:
# 0     BAB123032
# 1     BAB124015
# 2     BAB124016
# 3     BAB124024
# 4     BAB124025
#         ...
# 81    VIC124003
# 82    VIC124005
# 83    VND125032
# 84    VND125033
# 85    VPI124001
# Name: symbol, Length: 86, dtype: object

# %% [markdown]
# ### `all_covered_warrant()`
# Retrieve all covered warrants (group='CW').

# %%
df_all_covered_warrant = instance.all_covered_warrant()
display(df_all_covered_warrant)
# Out:
# 0      CACB2510
# 1      CACB2511
# 2      CACB2514
# 3      CACB2515
# 4      CACB2516
#          ...
# 261    CVRE2525
# 262    CVRE2526
# 263    CVRE2527
# 264    CVRE2601
# 265    CVRE2602
# Name: symbol, Length: 266, dtype: object

# %% [markdown]
# ### `all_etf()`
# Retrieve all ETF (exchange-traded funds).

# %%
df_all_etf = instance.all_etf()
display(df_all_etf)

# %% [markdown]
# ### `all_future_indices()`
# Retrieve all futures indices (group='FU_INDEX').

# %%
df_all_future_indices = instance.all_future_indices()
display(df_all_future_indices)
# Out:
# 0    41I1G4000
# 1    41I1G5000
# 2    41I1G6000
# 3    41I1G9000
# 4    41I2G4000
# 5    41I2G5000
# 6    41I2G6000
# 7    41I2G9000
# Name: symbol, dtype: object

# %% [markdown]
# ### `all_government_bonds()`
# Retrieve all government bonds.

# %%
df_all_government_bonds = instance.all_government_bonds()
display(df_all_government_bonds)
# Out:
# 0    41B5G6000
# 1    41B5G9000
# 2    41B5GC000
# 3    41BAG6000
# 4    41BAG9000
# 5    41BAGC000
# Name: symbol, dtype: object

# %% [markdown]
# ### `all_indices()`
# Retrieve all standardized market indices with metadata.

# %%
df_all_indices = instance.all_indices()
display(df_all_indices)
# Out:
#          symbol         name  \
# 0          VN30         VN30
# 1         VNMID        VNMID
# 2         VNSML        VNSML
# 3         VN100        VN100
# 4         VNALL        VNALL
# 5          VNSI         VNSI
# 6          VNIT         VNIT
# 7         VNIND        VNIND
# 8        VNCONS       VNCONS
# 9        VNCOND       VNCOND
# 10       VNHEAL       VNHEAL
# 11        VNENE        VNENE
# 12        VNUTI        VNUTI
# 13       VNREAL       VNREAL
# 14        VNFIN        VNFIN
# 15        VNMAT        VNMAT
# 16    VNDIAMOND    VNDIAMOND
# 17    VNFINLEAD    VNFINLEAD
# 18  VNFINSELECT  VNFINSELECT
# 19        VNX50        VNX50
# 20       VNXALL       VNXALL
#
#                                           description  \
# 0   30 cổ phiếu vốn hóa lớn nhất & thanh khoản tốt...
# 1    Mid-Cap Index - nhóm cổ phiếu vốn hóa trung bình
# 2         Small-Cap Index - nhóm cổ phiếu vốn hóa nhỏ
# 3               100 cổ phiếu có vốn hoá lớn nhất HOSE
# ...

# %% [markdown]
# ### `all_symbols()`
# Retrieve all symbols (filtered to STOCK).

# %%
df_all_symbols = instance.all_symbols()
display(df_all_symbols)
# Out:
#      symbol                                         organ_name
# 0       YTC  Công ty Cổ phần Xuất nhập khẩu Y tế Thành phố ...
# 1       YEG                     Công ty Cổ phần Tập đoàn Yeah1
# 2       YBM     Công ty Cổ phần Khoáng sản Công nghiệp Yên Bái
# 3       YBC      Công ty Cổ phần Xi măng và Khoáng sản Yên Bái
# 4       XPH                    Công ty Cổ phần Xà phòng Hà Nội
# ...     ...                                                ...
# 1734    AAS            Công ty Cổ phần Chứng khoán SmartInvest
# 1735    AAM                    Công ty Cổ Phần Thủy Sản MeKong
# 1736    AAH                           Công ty Cổ phần Hợp Nhất
# 1737    AAA                  Công ty Cổ phần Nhựa An Phát Xanh
# 1738    A32                                 Công ty Cổ phần 32
#
# [1739 rows x 2 columns]

# %% [markdown]
# ### `indices_by_group()`
# Retrieve standardized market indices by group/category.

# %%
df_indices_by_group = instance.indices_by_group()
display(df_indices_by_group)
# Out:
# None

# %% [markdown]
# ### `industries_icb()`
# Retrieve ICB code hierarchy and mapping.

# %%
df_industries_icb = instance.industries_icb()
display(df_industries_icb)
# Out:
#                                    icb_name  \
# 0                          Sản xuất Dầu khí
# 1    Thiết bị, Dịch vụ và Phân phối Dầu khí
# 2                                  Hóa chất
# 3                        Lâm nghiệp và Giấy
# 4                                  Kim loại
# ..                                      ...
# 150                                Internet
# 151                                Phần mềm
# 152                               Phần cứng
# 153                      Thiết bị văn phòng
# 154                     Thiết bị viễn thông
#
#                                 en_icb_name icb_code  level
# 0                       Oil & Gas Producers     0530      3
# 1    Oil Equipment, Services & Distribution     0570      3
# 2                                 Chemicals     1350      3
# 3                          Forestry & Paper     1730      3
# 4                Industrial Metals & Mining     1750      3
# ..                                      ...      ...    ...
# ...

# %% [markdown]
# ### `symbols_by_exchange()`
# Retrieve symbols by exchange/board.

# %%
df_symbols_by_exchange = instance.symbols_by_exchange()
display(df_symbols_by_exchange)
# Out:
#          symbol  exchange   type                          organ_short_name  \
# 0           YTC     UPCOM  STOCK                           XNK Y tế TP.HCM
# 1           YEG       HSX  STOCK                            Tập đoàn Yeah1
# 2           YBM       HSX  STOCK                     Khoáng sản CN Yên Bái
# 3           YBC     UPCOM  STOCK             Xi măng và Khoáng sản Yên Bái
# 4           XPH     UPCOM  STOCK                           Xà phòng Hà Nội
# ...         ...       ...    ...                                       ...
# 3310  41BAG3000  DELISTED     FU  10-year Government Bond   Futures 032026
# 3311  41B5GC000       HNX     FU  5-year Government Bond    Futures 122026
# 3312  41B5G9000       HNX     FU  5-year Government Bond    Futures 092026
# 3313  41B5G6000       HNX     FU  5-year Government Bond    Futures 062026
# 3314  41B5G3000  DELISTED     FU  5-year Government Bond    Futures 032026
#
# ...

# %% [markdown]
# ### `symbols_by_group()`
# Retrieve symbols by predefined group (VN30, HNX30, CW, etc.).

# %%
df_symbols_by_group = instance.symbols_by_group()
display(df_symbols_by_group)
# Out:
# 0     ACB
# 1     BID
# 2     CTG
# 3     DGC
# 4     FPT
# 5     GAS
# 6     GVR
# 7     HDB
# 8     HPG
# 9     LPB
# 10    MBB
# 11    MSN
# 12    MWG
# 13    PLX
# 14    SAB
# 15    SHB
# 16    SSB
# 17    SSI
# 18    STB
# 19    TCB
# 20    TPB
# 21    VCB
# 22    VHM
# 23    VIB
# 24    VIC
# 25    VJC
# 26    VNM
# 27    VPB
# 28    VPL
# 29    VRE
# Name: symbol, dtype: object

# %% [markdown]
# ### `symbols_by_industries()`
# Retrieve symbols grouped by ICB industries.

# %%
df_symbols_by_industries = instance.symbols_by_industries()
display(df_symbols_by_industries)
# Out:
#      symbol                                         organ_name com_type_code  \
# 0       A32                                 Công ty Cổ phần 32            CT
# 1       A32                                 Công ty Cổ phần 32            CT
# 2       A32                                 Công ty Cổ phần 32            CT
# 3       A32                                 Công ty Cổ phần 32            CT
# 4       AAA                  Công ty Cổ phần Nhựa An Phát Xanh            CT
# ...     ...                                                ...           ...
# 6187    YEG                     Công ty Cổ phần Tập đoàn Yeah1            CT
# 6188    YTC  Công ty Cổ phần Xuất nhập khẩu Y tế Thành phố ...            CT
# 6189    YTC  Công ty Cổ phần Xuất nhập khẩu Y tế Thành phố ...            CT
# 6190    YTC  Công ty Cổ phần Xuất nhập khẩu Y tế Thành phố ...            CT
# 6191    YTC  Công ty Cổ phần Xuất nhập khẩu Y tế Thành phố ...            CT
#
# ...
