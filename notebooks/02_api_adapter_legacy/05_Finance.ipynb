# %% [markdown]
# # API Adapter - Finance
# Demo tự động các hàm trong class `Finance`.

# %%
from vnstock_data.api.financial import Finance

# Khởi tạo instance
instance = Finance(source='vci', symbol='VNM')

# %% [markdown]
# ### `balance_sheet()`
# Retrieve balance sheet data.

# %%
df_balance_sheet = instance.balance_sheet(period='quarter')
display(df_balance_sheet)
# Out:
#                                       item  \
# 0                                 TÀI SẢN
# 1                      A. TÀI SẢN NGẮN HẠN
# 2    I. Tiền và các khoản tương đương tiền
# 3                                  1. Tiền
# 4            2. Các khoản tương đương tiền
# ..                                     ...
# 119         II. Nguồn kinh phí và quỹ khác
# 120                      1. Nguồn kinh phí
# 121   2. Nguồn kinh phí đã hình thành TSCĐ
# 122            C. LỢI ÍCH CỔ ĐÔNG THIỂU SỐ
# 123                    TỔNG CỘNG NGUỒN VỐN
#
#                                   item_id       2025-Q4       2025-Q3  \
# 0                                  assets           NaN           NaN
# 1                     a_short_term_assets  3.626118e+10  3.874685e+10
# 2             i_cash_and_cash_equivalents  1.794880e+09  5.154466e+09
# 3                                  1_cash  1.630880e+09  1.427466e+09
# 4                      2_cash_equivalents  1.640000e+08  3.727000e+09
# ...

# %% [markdown]
# ### `cash_flow()`
# Retrieve cash flow statement data.

# %%
df_cash_flow = instance.cash_flow(period='quarter')
display(df_cash_flow)
# Out:
#                                                  item  \
# 0          I. Lưu chuyển tiền từ hoạt động kinh doanh
# 1                             1. Lợi nhuận trước thuế
# 2                         2. Điều chỉnh cho các khoản
# 3                              Khấu hao TSCĐ và BĐSĐT
# 4                                  Các khoản dự phòng
# 5   Lãi, lỗ chênh lệch tỷ giá hối đoái do đánh giá...
# 6                         Lãi, lỗ từ hoạt động đầu tư
# 7                                     Chi phí lãi vay
# 8                            Lãi, lỗ từ thanh lý TSCĐ
# 9                          Thu nhập lãi vay và cổ tức
# 10                         Phân bổ lợi thế thương mại
# 11                      Điều chỉnh cho các khoản khác
# 12  3. Lợi nhuận từ hoạt động kinh doanh trước tha...
# 13                      Tăng, giảm các khoản phải thu
# 14                            Tăng, giảm hàng tồn kho
# 15  Tăng, giảm các khoản phải trả (không kể lãi va...
# ...

# %% [markdown]
# ### `income_statement()`
# Retrieve income statement data.

# %%
df_income_statement = instance.income_statement(period='quarter')
display(df_income_statement)
# Out:
#         report_period ticker         Sales  Sales deductions     Net sales  \
# period
# 2018-Q1       quarter    VNM  1.213196e+13     -1.146168e+10  1.212050e+13
# 2018-Q2       quarter    VNM  1.373845e+13     -3.596526e+10  1.370248e+13
# 2018-Q3       quarter    VNM  1.374350e+13     -8.238352e+09  1.373526e+13
# 2018-Q4       quarter    VNM  1.301532e+13     -1.161516e+10  1.300371e+13
# 2019-Q1       quarter    VNM  1.323008e+13     -4.078443e+10  1.318930e+13
# 2019-Q2       quarter    VNM  1.461040e+13     -1.144107e+10  1.459896e+13
# 2019-Q3       quarter    VNM  1.430404e+13     -1.314255e+10  1.429090e+13
# 2019-Q4       quarter    VNM  1.425570e+13     -1.673892e+10  1.423896e+13
# 2020-Q1       quarter    VNM  1.420619e+13     -5.309207e+10  1.415310e+13
# 2020-Q2       quarter    VNM  1.550959e+13     -1.435241e+10  1.549523e+13
# 2020-Q3       quarter    VNM  1.557723e+13     -1.407169e+10  1.556316e+13
# ...

# %% [markdown]
# ### `ratio()`
# Retrieve financial ratios.

# %%
df_ratio = instance.ratio(period='quarter')
display(df_ratio)
# Out:
#         report_period  Ratio TTM Id Ratio Type  Outstanding Shares (mil)  \
# period
# 2018-Q1       quarter       2699032  RATIO_TTM                1451246749
# 2018-Q2       quarter       2713643  RATIO_TTM                1741426616
# 2018-Q3       quarter       2715826  RATIO_TTM                1741407855
# 2018-Q4       quarter       2717446  RATIO_TTM                1741407855
# 2019-Q1       quarter       2722819  RATIO_TTM                1741378252
# 2019-Q2       quarter       2725720  RATIO_TTM                1741377694
# 2019-Q3       quarter       2730874  RATIO_TTM                1741377694
# 2019-Q4       quarter       2735058  RATIO_TTM                1741377694
# 2020-Q1       quarter       2748786  RATIO_TTM                1741377694
# 2020-Q2       quarter       2751865  RATIO_TTM                2089645346
# 2020-Q3       quarter       2754414  RATIO_TTM                2089645346
# 2020-Q4       quarter       2758236  RATIO_TTM                2089955445
# ...

# %% [markdown]
# ### `note()`
# Retrieve financial statement notes (thuyết minh báo cáo tài chính) if source is 'vci'.

# %%
df_note = instance.note(period='quarter')
display(df_note)
# Out:
#         report_period ticker  Cash and cash equivalents  Cash on hand  \
# period
# 2018-Q1       quarter    VNM               5.633927e+11  2.296740e+09
# 2018-Q2       quarter    VNM               1.343435e+12  1.891732e+09
# 2018-Q3       quarter    VNM               6.307847e+11  1.954583e+10
# 2018-Q4       quarter    VNM               1.522610e+12  1.853589e+09
# 2019-Q1       quarter    VNM               1.209154e+12  1.323867e+09
# 2019-Q2       quarter    VNM               1.676491e+12  2.515086e+09
# 2019-Q3       quarter    VNM               1.043474e+12  1.749186e+09
# 2019-Q4       quarter    VNM               2.665195e+12  2.104241e+09
# 2020-Q1       quarter    VNM               1.379712e+12  2.164384e+09
# 2020-Q2       quarter    VNM               2.176667e+12  1.668908e+09
# 2020-Q3       quarter    VNM               2.335881e+12  1.469261e+09
# 2020-Q4       quarter    VNM               2.111243e+12  1.347052e+09
# ...
