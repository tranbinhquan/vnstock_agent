# %% [markdown]
# # API Adapter - Macro
# Demo tự động các hàm trong class `Macro`.

# %%
from vnstock_data.api.macro import Macro

# Khởi tạo instance
instance = Macro()

# %% [markdown]
# ### `cpi()`
# Fetch CPI series.

# %%
df_cpi = instance.cpi()
display(df_cpi)
# Out:
#             last_updated                           name  value unit  \
# report_time
# 2016-04-30    2016-04-25                     Lương thực   1.11    %
# 2016-04-30    2016-04-25           Chỉ số giá tiêu dùng   0.33    %
# 2016-04-30    2016-04-25  So sánh với cùng kỳ năm trước   1.89    %
# 2016-04-30    2016-04-25        Đồ dùng và dịch vụ khác   0.10    %
# 2016-04-30    2016-04-25   Văn hóa, giải trí và du lịch  -0.01    %
# ...                  ...                            ...    ...  ...
# 2025-08-31    2025-09-05         Ăn uống ngoài gia đình   0.20    %
# 2025-08-31    2025-09-05                      Thực phẩm  -0.18    %
# 2025-08-31    2025-09-05                     Lương thực   0.01    %
# 2025-08-31    2025-09-05   Thiết bị và đồ dùng gia đình   0.11    %
# 2025-08-31    2025-09-05           Chỉ số giá tiêu dùng   0.05    %
#
#                         source
# report_time
# 2016-04-30   Tổng cục thống kê
# 2016-04-30   Tổng cục thống kê
# ...

# %% [markdown]
# ### `exchange_rate()`
# Fetch Exchange Rate series.

# %%
df_exchange_rate = instance.exchange_rate()
display(df_exchange_rate)
# Out:
#             last_updated                              name    value     unit  \
# report_time
# 2017-02-01    2017-01-31  Tỷ giá trung tâm (từ 04/01/2016)  22202.0  USD/VNĐ
# 2017-02-01    2017-01-31                    Liên ngân hàng      NaN  USD/VNĐ
# 2018-02-01    2018-01-31  Tỷ giá trung tâm (từ 04/01/2016)  22431.0  USD/VNĐ
# 2018-02-01    2018-01-31                    Liên ngân hàng      NaN  USD/VNĐ
# 2019-02-01    2019-01-31                    Liên ngân hàng      NaN  USD/VNĐ
# ...                  ...                               ...      ...      ...
# 2022-12-31    2022-12-30                    Liên ngân hàng      NaN  USD/VNĐ
# 2024-12-31    2024-12-30                    Liên ngân hàng      NaN  USD/VNĐ
# 2024-12-31    2024-12-30  Tỷ giá trung tâm (từ 04/01/2016)  24335.0  USD/VNĐ
# 2025-12-31    2025-12-30                    Liên ngân hàng      NaN  USD/VNĐ
# 2025-12-31    2025-12-30  Tỷ giá trung tâm (từ 04/01/2016)  25121.0  USD/VNĐ
#
# ...

# %% [markdown]
# ### `fdi()`
# Fetch Foreign Direct Investment series.

# %%
df_fdi = instance.fdi()
display(df_fdi)
# Out:
#             last_updated group_name       name  value    unit  \
# report_time
# 2016-04-30    2016-08-17   Tổng FDI    Đăng ký   2.85  Tỷ USD
# 2016-04-30    2016-08-17   Tổng FDI  Giải ngân   1.15  Tỷ USD
# 2016-04-30    2016-08-17   Tổng FDI    Đăng ký   2.85  Tỷ USD
# 2016-04-30    2016-08-17   Tổng FDI  Giải ngân   1.15  Tỷ USD
# 2016-05-31    2016-08-17   Tổng FDI    Đăng ký   3.28  Tỷ USD
# ...                  ...        ...        ...    ...     ...
# 2026-01-31    2026-02-05   Tổng FDI  Giải ngân   1.68  Tỷ USD
# 2026-02-28    2026-03-05   Tổng FDI    Đăng ký   3.45  Tỷ USD
# 2026-02-28    2026-03-05   Tổng FDI  Giải ngân   1.53  Tỷ USD
# 2026-03-31    2026-04-05   Tổng FDI    Đăng ký   9.17  Tỷ USD
# 2026-03-31    2026-04-05   Tổng FDI  Giải ngân   2.20  Tỷ USD
#
#                             source
# report_time
# 2016-04-30   Cục Đầu tư nước ngoài
# 2016-04-30   Cục Đầu tư nước ngoài
# 2016-04-30   Cục Đầu tư nước ngoài
# 2016-04-30   Cục Đầu tư nước ngoài
# ...

# %% [markdown]
# ### `gdp()`
# Fetch GDP series.

# %%
df_gdp = instance.gdp()
display(df_gdp)
# Out:
#             last_updated                     group_name         name  \
# report_time
# 2016-03-01    2016-03-29  Cơ cấu GDP  theo giá hiện tại  Công nghiệp
# 2016-03-01    2016-03-29  Cơ cấu GDP  theo giá hiện tại      Dịch vụ
# 2016-03-01    2016-03-29  Cơ cấu GDP  theo giá hiện tại  Nông nghiệp
# 2016-03-01    2016-03-29             Giá trị GDP (2010)  Công nghiệp
# 2016-03-01    2016-03-29             Giá trị GDP (2010)      Dịch vụ
# ...                  ...                            ...          ...
# 2025-09-01    2025-10-05       Tăng trưởng thực của GDP      Dịch vụ
# 2025-09-30    2025-10-05       Tăng trưởng thực của GDP  Nông nghiệp
# 2025-09-01    2025-10-05       Tăng trưởng thực của GDP  Nông nghiệp
# 2025-09-30    2025-10-05       Tăng trưởng thực của GDP     Tổng GDP
# 2025-09-01    2025-10-05       Tăng trưởng thực của GDP     Tổng GDP
#
#                  value    unit             source report_type
# report_time
# ...

# %% [markdown]
# ### `import_export()`
# Fetch Import-Export series.

# %%
df_import_export = instance.import_export()
display(df_import_export)
# Out:
#             last_updated                            name     value       unit  \
# report_time
# 2016-04-30    2016-04-27          Tổng trị giá Nhập khẩu  14000.00  Triệu USD
# 2016-04-30    2016-04-27                Máy móc thiết bị    750.00  Triệu USD
# 2016-04-30    2016-04-27                Điện tử máy tính   1300.00  Triệu USD
# 2016-04-30    2016-04-27                 Thức ăn gia súc    280.00  Triệu USD
# 2016-04-30    2016-04-27                            Café    271.00  Triệu USD
# ...                  ...                             ...       ...        ...
# 2025-07-31    2025-08-06  Điện tử, máy tính và linh kiện  13839.05  Triệu USD
# 2025-07-31    2025-08-06          Tổng trị giá Xuất khẩu  42265.54  Triệu USD
# 2025-07-31    2025-08-06          Tổng trị giá Nhập khẩu  39998.52  Triệu USD
# 2025-07-31    2025-08-06                        Thủy sản    971.58  Triệu USD
# 2025-07-31    2025-08-06                Máy móc thiết bị   5309.44  Triệu USD
#
# ...

# %% [markdown]
# ### `industry_prod()`
# Fetch Industrial Production series.

# %%
df_industry_prod = instance.industry_prod()
display(df_industry_prod)
# Out:
#             last_updated   group_name  \
# report_time
# 2016-04-30    2016-04-26  Tăng trưởng
# 2016-04-30    2016-04-26  Tăng trưởng
# 2016-04-30    2016-04-26  Tăng trưởng
# 2016-04-30    2016-04-26  Tăng trưởng
# 2016-04-30    2016-04-26  Tăng trưởng
# ...                  ...          ...
# 2025-07-31    2025-08-06  Tăng trưởng
# 2025-07-31    2025-08-06  Tăng trưởng
# 2025-07-31    2025-08-06  Tăng trưởng
# 2025-07-31    2025-08-06  Tăng trưởng
# 2025-07-31    2025-08-06  Tăng trưởng
#
#                                                           name  value unit  \
# report_time
# 2016-04-30                              Toàn ngành công nghiệp -11.70    %
# 2016-04-30   Cung cấp nước, hoạt động quản lý và xử lý rác ...   2.40    %
# 2016-04-30                                         Khai khoáng -10.20    %
# 2016-04-30                       Công nghiệp chế biến, chế tạo   0.50    %
# 2016-04-30                          Sản xuất và Phân phối điện   2.70    %
# ...

# %% [markdown]
# ### `interest_rate()`
# Fetch Interest Rate series.

# %%
df_interest_rate = instance.interest_rate()
display(df_interest_rate)
# Out:
# 2026-04-10 23:12:49 - vnstock_data.core.utils.client - ERROR - API request failed: Expecting value: line 1 column 2 (char 1)
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~/.venv/lib/python3.13/site-packages/requests/models.py:978, in Response.json(self, **kwargs)
#     977 try:
# --> 978     return complexjson.loads(self.text, **kwargs)
#     979 except JSONDecodeError as e:
#     980     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     981     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~/.venv/lib/python3.13/site-packages/simplejson/__init__.py:514, in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, use_decimal, allow_nan, **kw)
#     510 if (cls is None and encoding is None and object_hook is None and
# ...

# %% [markdown]
# ### `money_supply()`
# Fetch Money Supply series.

# %%
df_money_supply = instance.money_supply()
display(df_money_supply)
# Out:
#             last_updated                      name        value    unit  \
# report_time
# 2016-04-30    2016-09-14      Tăng trưởng tín dụng         4.06       %
# 2016-04-30    2016-09-14              Cung tiền M2   6326334.00  Tỷ VNĐ
# 2016-04-30    2016-09-14  Tăng trưởng Cung tiền M2         5.10       %
# 2016-04-30    2016-09-14                  Tín dụng   4845059.00  Tỷ VNĐ
# 2016-05-31    2016-09-14      Tăng trưởng tín dụng         5.49       %
# ...                  ...                       ...          ...     ...
# 2025-12-31    2026-03-03              Cung tiền M2          NaN  Tỷ VNĐ
# 2026-01-31    2026-03-22      Tăng trưởng tín dụng         1.19       %
# 2026-01-31    2026-03-22  Tăng trưởng Cung tiền M2          NaN       %
# 2026-01-31    2026-03-22                  Tín dụng  18815882.09  Tỷ VNĐ
# 2026-01-31    2026-03-22              Cung tiền M2          NaN  Tỷ VNĐ
#
#                                   source
# report_time
# ...

# %% [markdown]
# ### `population_labor()`
# Fetch Population and Labor series.

# %%
df_population_labor = instance.population_labor()
display(df_population_labor)
# Out:
#             last_updated                          name   value         unit  \
# report_time
# 2016          2017-01-03             Số lượng lao động   53.29  Triệu người
# 2016          2017-01-03   Tỷ lệ thất nghiệp thành thị    3.21            %
# 2016          2017-01-03                      Tỷ lệ nữ   50.35            %
# 2016          2017-01-03                     Tỷ lệ nam   49.65            %
# 2016          2017-01-03         Tỷ lệ lao động/dân số   57.20            %
# ...                  ...                           ...     ...          ...
# 2024          2025-07-13  Nông, lâm nghiệp và thủy sản   13.67  Triệu người
# 2024          2025-07-06                        Dân số  101.30  Triệu người
# 2024          2025-07-13             Số lượng lao động   52.90  Triệu người
# 2024          2025-07-13                       Dịch vụ   20.80  Triệu người
# 2024          2025-07-13   Tỷ lệ thất nghiệp thành thị    2.53            %
#
#             source
# report_time
# ...

# %% [markdown]
# ### `retail()`
# Fetch Retail sales series.

# %%
df_retail = instance.retail()
display(df_retail)
# Out:
#             last_updated                      name      value    unit  \
# report_time
# 2016-04-30    2016-04-26                  TỔNG SỐ:  279806.50  Tỷ VNĐ
# 2016-04-30    2016-04-26              Dịch vụ khác   32984.50  Tỷ VNĐ
# 2016-04-30    2016-04-26           Bán lẻ hàng hóa  214652.10  Tỷ VNĐ
# 2016-04-30    2016-04-26  Dịch vụ lưu trú, ăn uống   29956.90  Tỷ VNĐ
# 2016-04-30    2016-04-26           Du lịch lữ hành    2213.00  Tỷ VNĐ
# ...                  ...                       ...        ...     ...
# 2026-03-31    2026-04-05                  TỔNG SỐ:  638594.08  Tỷ VNĐ
# 2026-03-31    2026-04-05           Bán lẻ hàng hóa  485833.37  Tỷ VNĐ
# 2026-03-31    2026-04-05  Dịch vụ lưu trú, ăn uống   80309.63  Tỷ VNĐ
# 2026-03-31    2026-04-05           Du lịch lữ hành    7808.00  Tỷ VNĐ
# 2026-03-31    2026-04-05              Dịch vụ khác   64643.07  Tỷ VNĐ
#
#                         source
# report_time
# 2016-04-30   Tổng cục thống kê
# 2016-04-30   Tổng cục thống kê
# ...
