# %% [markdown]
# # API Adapter - TopStock
# Demo tự động các hàm trong class `TopStock`.

# %%
from vnstock_data.api.insight import TopStock

# Khởi tạo instance
instance = TopStock(source='VND', symbol='VNM')

# %% [markdown]
# ### `deal()`
# Top 10 by block trade volume in the given index.

# %%
df_deal = instance.deal()
display(df_deal)
# Out:
#   symbol    index  last_price      last_updated  price_change_1d  \
# 0    SIP  VNINDEX       60.80  2026-04-10 15:59            -0.60
# 1    SSB  VNINDEX       17.15  2026-04-10 15:59             0.00
# 2    BKG  VNINDEX        2.59  2026-04-10 15:59             0.01
# 3    SCR  VNINDEX        6.25  2026-04-10 15:59             0.00
# 4    FRT  VNINDEX      152.00  2026-04-10 15:59             2.00
# 5    HDB  VNINDEX       26.15  2026-04-10 15:59             0.10
# 6    BSI  VNINDEX       37.00  2026-04-10 15:59            -0.20
# 7    KDC  VNINDEX       48.80  2026-04-10 15:59             0.00
# 8    VIX  VNINDEX       18.05  2026-04-10 15:59             0.05
# 9    VPB  VNINDEX       27.30  2026-04-10 15:59             0.20
#
#    price_change_pct_1d  accumulated_value  avg_volume_20d  \
# 0            -0.977199       1.163815e+10        293070.0
# 1             0.000000       4.043406e+10       1935965.0
# 2             0.387597       9.127040e+08         77260.0
# ...

# %% [markdown]
# ### `foreign_buy()`
# Top 10 net foreign buys on the given date.

# %%
df_foreign_buy = instance.foreign_buy()
display(df_foreign_buy)
# Out:
#   symbol        date     net_value
# 0    TCB  2026-04-10  2.179768e+11
# 1    HPG  2026-04-10  1.796444e+11
# 2    MBB  2026-04-10  1.005341e+11
# 3    VNM  2026-04-10  9.388876e+10
# 4    MSN  2026-04-10  7.162151e+10
# 5    BSR  2026-04-10  7.095849e+10
# 6    DXG  2026-04-10  5.452718e+10
# 7    VCB  2026-04-10  5.211277e+10
# 8    VCI  2026-04-10  5.073029e+10
# 9    NVL  2026-04-10  5.062585e+10

# %% [markdown]
# ### `foreign_sell()`
# Top 10 net foreign sells on the given date.

# %%
df_foreign_sell = instance.foreign_sell()
display(df_foreign_sell)
# Out:
#   symbol        date     net_value
# 0    BID  2026-04-10 -6.847928e+10
# 1    VHM  2026-04-10 -4.371136e+10
# 2    FRT  2026-04-10 -3.735763e+10
# 3    VPB  2026-04-10 -3.394367e+10
# 4    KDH  2026-04-10 -3.345910e+10
# 5    MWG  2026-04-10 -3.074975e+10
# 6    GAS  2026-04-10 -2.680528e+10
# 7    ACB  2026-04-10 -2.355309e+10
# 8    FPT  2026-04-10 -1.402052e+10
# 9    VIX  2026-04-10 -1.398705e+10

# %% [markdown]
# ### `gainer()`
# Top 10 gainers in the given index.

# %%
df_gainer = instance.gainer()
display(df_gainer)
# Out:
#   symbol    index  last_price      last_updated  price_change_1d  \
# 0    BSR  VNINDEX       26.75  2026-04-10 15:59             1.75
# 1    VVS  VNINDEX      105.90  2026-04-10 15:59             6.90
# 2    CCC  VNINDEX        8.07  2026-04-10 15:59             0.52
# 3    SMC  VNINDEX       13.35  2026-04-10 15:59             0.85
# 4    TDG  VNINDEX        2.74  2026-04-10 15:59             0.14
# 5    MSB  VNINDEX       12.75  2026-04-10 15:59             0.65
# 6    PVD  VNINDEX       33.90  2026-04-10 15:59             1.50
# 7    TCB  VNINDEX       32.25  2026-04-10 15:59             1.35
# 8    BFC  VNINDEX       57.90  2026-04-10 15:59             2.40
# 9    PLX  VNINDEX       41.15  2026-04-10 15:59             1.65
#
#    price_change_pct_1d  accumulated_value  avg_volume_20d  \
# 0             7.000000       5.280704e+11      17905615.0
# 1             6.969697       1.385209e+10        263025.0
# 2             6.887417       3.599870e+08         10465.0
# ...

# %% [markdown]
# ### `loser()`
# Top 10 losers in the given index.

# %%
df_loser = instance.loser()
display(df_loser)
# Out:
#   symbol    index  last_price      last_updated  price_change_1d  \
# 0    DCL  VNINDEX       41.85  2026-04-10 15:59            -3.15
# 1    BVH  VNINDEX       76.40  2026-04-10 15:59            -3.40
# 2    C47  VNINDEX       10.40  2026-04-10 15:59            -0.45
# 3    CRE  VNINDEX        7.70  2026-04-10 15:59            -0.25
# 4    VPG  VNINDEX        3.81  2026-04-10 15:59            -0.12
# 5    DSC  VNINDEX       13.10  2026-04-10 15:59            -0.40
# 6    CVT  VNINDEX       24.95  2026-04-10 15:59            -0.75
# 7    DQC  VNINDEX        9.00  2026-04-10 15:59            -0.25
# 8    NBB  VNINDEX       18.00  2026-04-10 15:59            -0.40
# 9    PET  VNINDEX       48.50  2026-04-10 15:59            -1.05
#
#    price_change_pct_1d  accumulated_value  avg_volume_20d  \
# 0            -7.000000       4.093038e+10        645810.0
# 1            -4.260652       1.227322e+11        757820.0
# 2            -4.147465       1.369850e+08         78590.0
# ...

# %% [markdown]
# ### `value()`
# Top 10 by trading value in the given index.

# %%
df_value = instance.value()
display(df_value)
# Out:
#   symbol    index  last_price      last_updated  price_change_1d  \
# 0    SHB  VNINDEX       15.40  2026-04-10 15:59            -0.10
# 1    HPG  VNINDEX       28.00  2026-04-10 15:59            -0.25
# 2    TCB  VNINDEX       32.25  2026-04-10 15:59             1.35
# 3    MBB  VNINDEX       26.70  2026-04-10 15:59             0.20
# 4    VIX  VNINDEX       18.05  2026-04-10 15:59             0.05
# 5    EIB  VNINDEX       23.10  2026-04-10 15:59             0.50
# 6    STB  VNINDEX       66.90  2026-04-10 15:59             0.60
# 7    SSI  VNINDEX       28.60  2026-04-10 15:59            -0.15
# 8    BSR  VNINDEX       26.75  2026-04-10 15:59             1.75
# 9    FPT  VNINDEX       77.70  2026-04-10 15:59            -0.60
#
#    price_change_pct_1d  accumulated_value  avg_volume_20d  \
# 0            -0.645161       1.621547e+12      69944440.0
# 1            -0.884956       1.004138e+12      33529855.0
# 2             4.368932       9.864523e+11      12023260.0
# ...

# %% [markdown]
# ### `volume()`
# Top 10 by abnormal volume in the given index.

# %%
df_volume = instance.volume()
display(df_volume)
# Out:
#   symbol    index  last_price      last_updated  price_change_1d  \
# 0    HSL  VNINDEX        5.00  2026-04-10 15:59             0.09
# 1    QCG  VNINDEX       14.75  2026-04-10 15:59             0.35
# 2    CDC  VNINDEX       23.40  2026-04-10 15:59             0.00
# 3    THG  VNINDEX       45.30  2026-04-10 15:59             1.05
# 4    MSB  VNINDEX       12.75  2026-04-10 15:59             0.65
# 5    BKG  VNINDEX        2.59  2026-04-10 15:59             0.01
# 6    CCC  VNINDEX        8.07  2026-04-10 15:59             0.52
# 7    CNG  VNINDEX       25.20  2026-04-10 15:59             0.55
# 8    VNS  VNINDEX        8.01  2026-04-10 15:59            -0.12
# 9    GSP  VNINDEX       11.30  2026-04-10 15:59             0.05
#
#    price_change_pct_1d  accumulated_value  avg_volume_20d  \
# 0             1.832994       7.567704e+09        194645.0
# 1             2.430556       3.074446e+10        420590.0
# 2             0.000000       3.624154e+10        335140.0
# ...
