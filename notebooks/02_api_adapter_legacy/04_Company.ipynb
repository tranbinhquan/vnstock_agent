# %% [markdown]
# # API Adapter - Company
# Demo tự động các hàm trong class `Company`.

# %%
from vnstock_data.api.company import Company

# Khởi tạo instance
instance = Company(source='VCI', symbol='VNM')

# %% [markdown]
# ### `affiliate()`
# Retrieve company affiliate data.

# %%
df_affiliate = instance.affiliate()
display(df_affiliate)
# Out:
#          id sub_organ_code                           organ_name  \
# 0  29026516           APIS                 Công ty Cổ phần APIS
# 1  29026517    ASIACOCONUT  Công ty Cổ phần Chế Biến Dừa Á Châu
# 2  29026518     F000001208               Miraka Holding Limited
#
#    ownership_percent
# 0             0.2000
# 1             0.2496
# 2             0.1355

# %% [markdown]
# ### `capital_history()`
# Retrieve company charter capital history.

# %%
df_capital_history = instance.capital_history()
display(df_capital_history)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File ~/.venv/lib/python3.13/site-packages/tenacity/__init__.py:474, in Retrying.__call__(self, fn, *args, **kwargs)
#     473 try:
# --> 474     result = fn(*args, **kwargs)
#     475 except BaseException:  # noqa: B902
#
# File ~/.venv/lib/python3.13/site-packages/vnstock_data/base.py:13, in dynamic_method.<locals>.B(self, *D, **E)
#      12 B=self
# ---> 13 if not hasattr(B._provider,A):raise NotImplementedError("Source '"+B.source+"' does not support '"+A+"'")
#      14 C=getattr(B._provider,A);F=inspect.signature(C);G={A:B for(A,B)in E.items()if A in F.parameters};return C(*D,**G)
#
# NotImplementedError: Source 'VCI' does not support 'capital_history'
#
# The above exception was the direct cause of the following exception:
#
# RetryError                                Traceback (most recent call last)
# Cell In[21], line 1
# ...

# %% [markdown]
# ### `events()`
# Retrieve company events.

# %%
df_events = instance.events()
display(df_events)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### `news()`
# Retrieve company news.

# %%
df_news = instance.news()
display(df_news)
# Out:
#                                                 head  article_id  \
# 0  Trong bối cảnh thị trường đầy biến động, khả n...     1413395
#
#                                                title         publish_time  \
# 0  Vị thế tiền mặt ròng là gì và ai đang đứng đầu...  2026-03-18T11:02:00
#
#                                                  url
# 0  /2026/03/vi-the-tien-mat-rong-la-gi-va-ai-dang...

# %% [markdown]
# ### `officers()`
# Retrieve company officers data.

# %%
df_officers = instance.officers()
display(df_officers)
# Out:
#      from_date                          position                      name  \
# 0   TV Độc lập                            CTHĐQT      Ông Nguyễn Hạnh Phúc
# 1   TV Độc lập  TVHĐQT/Chủ tịch Ủy ban Kiểm toán            Ông Đỗ Lê Hùng
# 2         2018        TVHĐQT/TV Ủy ban Kiểm toán     Ông Alain Xavier Cany
# 3         2017        TVHĐQT/TV Ủy ban Kiểm toán        Bà Đặng Thị Thu Hà
# 4         2017        TVHĐQT/TV Ủy ban Kiểm toán  Ông Michael Chye Hin Fah
# 5         1994               TVHĐQT/GĐ Tài chính         Ông Lê Thành Liêm
# 6         1976                        TGĐ/TVHĐQT          Bà Mai Kiều Liên
# 7   TV Độc lập                            TVHĐQT         Bà Tiêu Yến Trinh
# 8         2025                            TVHĐQT    Bà Tongjai ThanaCHanan
# 9         2025                            TVHĐQT           Ông Vũ Trí Thức
# 10        2005                      GĐ Điều hành          Bà Bùi Thị Hương
# ...

# %% [markdown]
# ### `overview()`
# Retrieve company overview data.

# %%
df_overview = instance.overview()
display(df_overview)
# Out:
#                                       business_model symbol founded_date  \
# 0  \n- Chế biến, sản xuất kinh doanh sữa và các s...    VNM   01/10/2003
#
#    charter_capital  number_of_employees listing_date  par_value exchange  \
# 0            20900                 9906   19/01/2006      10000     HOSE
#
#    listing_price  listed_volume  ...              phone  \
# 0          53000           2090  ...  (84.28) 5415 5555
#
#                              fax                     email  \
# 0  (84.28) 5416 1226 - 5416 1230  vinamilk@vinamilk.com.vn
#
#                        website  \
# 0  https://www.vinamilk.com.vn
#
#                                             branches  \
# 0  - Tại Hà Nội: 57 Trần Duy Hưng - P. Trung Hòa ...
#
#                                              history free_float_percentage  \
# 0  \n- Năm 1976: Tiền thân của công ty là Công ty...        20899554450000
#
#   free_float outstanding_shares           as_of_date
# ...

# %% [markdown]
# ### `shareholders()`
# Retrieve company shareholders data.

# %%
df_shareholders = instance.shareholders()
display(df_shareholders)
# Out:
#                                              name          update_date  \
# 0  Tổng Công ty Đầu tư và Kinh doanh Vốn Nhà nước  2025-08-29T00:00:00
# 1                   F&N Dairy Investments Pte Ltd  2025-12-22T00:00:00
#
#    shares_owned  ownership_percentage
# 0     752476602                 36.00
# 1     465847490                 22.29

# %% [markdown]
# ### `subsidiaries()`
# Retrieve company subsidiaries data.

# %%
df_subsidiaries = instance.subsidiaries()
display(df_subsidiaries)
# Out:
#             update_date                                          name  \
# 0   2025-12-31T00:00:00  Công ty TNHH MTV Bò Sữa Thống Nhất Thanh Hóa
# 1   2025-12-31T00:00:00           Driftwood Dairy Holding Corporation
# 2   2025-12-31T00:00:00                Angkor Dairy Products Co., Ltd
# 3   2025-12-31T00:00:00              Công ty TNHH MTV Bò Sữa Việt Nam
# 4   2025-12-31T00:00:00  Công ty TNHH MTV Bò Sữa Thống Nhất Thanh Hóa
# 5   2025-12-31T00:00:00                Angkor Dairy Products Co., Ltd
# 6   2025-12-31T00:00:00              Công ty TNHH MTV Bò Sữa Việt Nam
# 7   2025-12-31T00:00:00   Lao-Jagro Development XiengKhouang Co., Ltd
# 8   2025-12-31T00:00:00        Tổng Công ty Chăn nuôi Việt Nam - CTCP
# 9   2025-12-31T00:00:00        Tổng Công ty Chăn nuôi Việt Nam - CTCP
# 10  2025-12-31T00:00:00                           CTCP Đường Việt Nam
# 11  2025-12-31T00:00:00                    CTCP Giống Bò sữa Mộc Châu
# ...
