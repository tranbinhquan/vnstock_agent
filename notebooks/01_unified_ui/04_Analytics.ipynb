# %% [markdown]
# # Unified UI - Analytics Layer (Lớp Phân Tích Định Giá 📊)
#
# Notebook này minh hoạ cơ chế truy xuất toàn bộ các phương thức thuộc Analytics Domain.
# Lớp Analytics chủ yếu cung cấp số liệu định giá thị trường nâng cao (P/E, P/B vĩ mô) cho các tập hợp Index.
#
# ---
#
# ### Sử dụng với Jupyter Notebook (Trong IDE)
#
# Khi chạy Jupyter Notebook trực tiếp trong IDE (như Antigravity, VS Code, Cursor), để sử dụng được môi trường ảo `~/.venv`, bạn cần đăng ký nó dưới dạng một Kernel.
#
# <details>
# <summary><b>💡 <i>Click để xem hướng dẫn thiết lập chi tiết</i></b></summary>
# <br>
# Khi chạy Jupyter Notebook trực tiếp trong IDE (như Antigravity, VS Code, Cursor), để sử dụng được môi trường ảo `~/.venv`, bạn cần đăng ký nó dưới dạng một Kernel.
#
# **1. Kích hoạt môi trường ảo**
# (Mặc định do Vnstock Installer tạo ra, bạn có thể chỉnh lại path nếu cài ở vị trí khác)
# ```bash
# # macOS / Linux
# source ~/.venv/bin/activate
# # Windows
# ~\.venv\Scripts\activate
# ```
#
# **2. Cài đặt thư viện kết nối (`ipykernel`)**
# ```bash
# python -m pip install ipykernel
# ```
#
# **3. Đăng ký Kernel với Jupyter**
# ```bash
# python -m ipykernel install --user --name=vnstock-venv --display-name "Python (Vnstock)"
# ```
#
# **4. Chọn Kernel trong IDE**
# Nhìn góc trên bên phải Notebook, click vào tên Kernel hiện tại (vd: *Select Kernel* hoặc *Python 3.x.x*).
# Chọn **Python (Vnstock)** từ danh sách. (Tải lại cửa sổ nếu chưa thấy bằng tổ hợp phím `Ctrl`/`Cmd` + `Shift` + `P` sau đó tìm lệnh `Developer: Reload Window`).
# </details>

# %%
from vnstock_data import Analytics
from IPython.display import display

# Initialize Analytics layer
ana = Analytics()

# %% [markdown]
# ### 1. Market Valuation (Định Giá Thị Trường & Chỉ Số)
#
# Truy xuất lịch sử định giá của các rổ chỉ số vĩ mô như VNINDEX, HNX qua các tỷ số kinh điển P/E, P/B và đánh giá tổng quan.

# %% [markdown]
# **Lịch sử định giá P/E 5 năm gần nhất của VNINDEX (P/E History)**

# %%
df = ana.valuation('VNINDEX').pe(duration='5Y')
display(df.tail())
# Out:
#                    pe
# reportDate
# 2026-04-06  13.939022
# 2026-04-07  13.935969
# 2026-04-08  14.594829
# 2026-04-09  14.429553
# 2026-04-10  14.540357

# %% [markdown]
# **Lịch sử định giá P/B 3 năm của HNX (P/B History)**

# %%
df = ana.valuation('HNX').pb(duration='3Y')
display(df.tail())
# Out:
#                   pb
# reportDate
# 2026-04-06  1.526244
# 2026-04-07  1.534405
# 2026-04-08  1.571082
# 2026-04-09  1.555736
# 2026-04-10  1.560591

# %% [markdown]
# **Bảng thống kê đánh giá tổng hợp mức độ đắt/rẻ của Thị trường (Market Evaluation Summary)**

# %%
df = ana.valuation('VNINDEX').evaluation(duration='1Y')
display(df.head())
# Out:
#                    pe        pb
# reportDate
# 2025-04-14  12.325832  1.595038
# 2025-04-15  12.186329  1.577515
# 2025-04-16  12.012701  1.555015
# 2025-04-17  12.080348  1.563572
# 2025-04-18  12.091276  1.565399
